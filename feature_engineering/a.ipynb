# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

df=pd.read_csv('../melb_data.csv')
df.head()
# Out:
#        Suburb           Address  ...             Regionname Propertycount
# 0  Abbotsford      85 Turner St  ...  Northern Metropolitan        4019.0
# 1  Abbotsford   25 Bloomburg St  ...  Northern Metropolitan        4019.0
# 2  Abbotsford      5 Charles St  ...  Northern Metropolitan        4019.0
# 3  Abbotsford  40 Federation La  ...  Northern Metropolitan        4019.0
# 4  Abbotsford       55a Park St  ...  Northern Metropolitan        4019.0
#
# [5 rows x 21 columns]

# %%
X = df.select_dtypes(include="number").copy()
Y = X.pop("Price")

baseline = RandomForestRegressor(criterion="absolute_error", random_state=0)
baseline_score = cross_val_score(
    baseline, X, Y, cv=5, scoring='neg_mean_absolute_error'
)
baseline_score = -1 * baseline_score.mean()

print(f"MAE Baseline Score : {baseline_score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 5
#       1 X = df.select_dtypes(include="number").copy()
#       2 Y = X.pop("Price")
#       3
#       4 baseline = RandomForestRegressor(criterion="absolute_error", random_state=0)
# ----> 5 baseline_score = cross_val_score(
#       6     baseline, X, Y, cv=5, scoring='neg_mean_absolute_error'
#       7 )
#       8 baseline_score = -1 * baseline_score.mean()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
# ...

# %%
X=df.copy()
Y=X.pop("CompressiveStrength")

X['FCRatio']=X['FineAggregate']/X["CoarseAgrregate"]
X['AggCmtRatio']=X["CoarseAgrregate"]+X["FineAggregate"]/X["Cement"]
X["WaterCmtRatio"]=X["Water"]/X["Cement"]

model=RandomForestRegressor(criterion="absolute_error",random_state=0)

scores=cross_val_score(
    model,X,y,cv=5,scoring="neg_mean_absolute_error"
)

scores=-1 * score.mean()

print(f"Mae scores with ratio features:{scores:.4}")
